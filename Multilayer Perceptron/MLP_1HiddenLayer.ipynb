# %%
from keras.utils.np_utils import to_categorical
import time
import numpy as np
import matplotlib.pyplot as plt
from sklearn import datasets
from sklearn.model_selection import StratifiedShuffleSplit
import random
from sklearn.model_selection import KFold

# %%
seed = 50  
random.seed(seed)

# %%
iris = datasets.load_iris()

X = iris['data']  # selecting all features
Y = (iris['target'])  # selecting all labels
Y = to_categorical(Y)  # converting labels to one-hot encoding

# %% [markdown]
# #### Stratified Shuffle Split for initial training

# %%
sample = StratifiedShuffleSplit(n_splits=1, test_size=0.2, random_state=seed)

for train, test in sample.split(X, Y):
    x_train, x_test, y_train, y_test = X[train], X[test], Y[train], Y[test]

# %%
class MultiLayerPerceptron():
    def __init__(self, layer_sizes, epochs=10, learning_rate=0.001, regularization='none', regularization_rate=0.001, activation='sigmoid'):
        """
        Parameters
        ------------
        learning_rate : float
            Learning rate (between 0.0 and 1.0 preferred).
        epochs : int
            number of passes over the training dataset.
        regularization : string
            'l1' , 'l2' or 'none'
        regularization_rate: float
            L1 and L2 regularization parameter
        activation : string
            'sigmoid', 'tanh' or 'relu'
        layer_sizes : list
            list of integers, each integer is the number of nodes in a layer.

        Attributes
        -----------
        weights_ : 1d-array
            Weights after fitting.
        errors_ : list
            Number of misclassifications in every epoch.
        cache_ : dict
            to store network parameters and intermediate results.
        """

        self.layer_sizes = layer_sizes
        self.epochs = epochs
        self.learning_rate = learning_rate
        self.errors_ = []
        self.regularization_rate = regularization_rate
        self.regularization = regularization
        self.activation = activation
        self.cache_ = self.initialization()

    def relu(self, X, derivative=False):
        if derivative:
            return np.where(X > 0, 1, 0)
        return np.maximum(0, X)

    def tanh(self, X, derivative=False):
        if derivative:
            return 1 - np.square(np.tanh(X))
        return np.tanh(X)

    def sigmoid(self, X, derivative=False):
        if derivative:
            return (np.exp(-X)) / ((np.exp(-X) + 1) ** 2)
        return 1 / (1 + np.exp(-X))

    def softmax(self, X, derivative=False):
        # Numerically stable with large exponentials to avoid log(0)
        exps = np.exp(X - X.max())
        if derivative:
            return exps / np.sum(exps, axis=0) * (1 - exps / np.sum(exps, axis=0))
        return exps / np.sum(exps, axis=0)

    def initialization(self):
        """
        Initialize the weights and number of nodes in layer of the network.
        Returns
        -------
        [params]
            dictionary of weights and number of nodes in layer.
        """
        seed = 50
        np.random.seed(seed)
        # number of nodes in each layer
        input_layer = self.layer_sizes[0]
        hidden_1 = self.layer_sizes[1]
        output_layer = self.layer_sizes[2]

        params = {
            'W2': np.random.randn(output_layer, hidden_1),
            'B2': np.zeros(output_layer, ),
            'W1': np.random.randn(hidden_1, input_layer),
            'B1': np.zeros(hidden_1, ),
        }

        return params

    def forward_propagate(self, X):
        """
        This function does a forward pass of x, and returns the output of the network.
        
        returns
        -------
        [params[3]]
            output of the network.
        """
        params = self.cache_
        params['A0'] = X

        # forward propagation to hidden layer 1
        params['Z1'] = np.dot(params["W1"], X) + params['B1']

        # hidden layer 1 activation
        if self.activation == 'relu':
            params['A1'] = self.relu(params['Z1'])
        elif self.activation == 'tanh':
            params['A1'] = self.tanh(params['Z1'])
        else:
            params['A1'] = self.sigmoid(params['Z1'])

        # forward propagation to hidden layer 2
        params['Z2'] = np.dot(params["W2"], params['A1']) + params['B2']
        params['A2'] = self.softmax(params['Z2'])

        return params['A2']  # return the output of the network

    def back_propagate(self, Y, output):
        '''
        This is the backpropagation algorithm, for calculating the gradients or derivatives
        of the neural network's parameters.

        returns
        -------
        [grads]
            dictionary of gradients of the network's parameters.
        '''
        params = self.cache_
        grads = {}
        m = len(Y)

        ## =========================== Regularization L2 =========================== ##

        if self.regularization == 'l2':

            # Calculate W2 update
            error = 2 * (output - Y) / output.shape[0] * self.softmax(params['Z2'], derivative=True) 
            grads['W2'] = np.outer(error, params['A1']) + (self.regularization_rate * self.cache_['W2']) / m
            grads['B2'] = np.sum(error, axis=0)

            # Calculate W1 update
            if self.activation == 'relu':
                error = np.dot(params['W2'].T, error) * self.relu(params['Z1'], derivative=True)
            elif self.activation == 'tanh':
                error = np.dot(params['W2'].T, error) * self.tanh(params['Z1'], derivative=True)
            else:
                error = np.dot(params['W2'].T, error) * self.sigmoid(params['Z1'], derivative=True)

            grads['W1'] = np.outer(error, params['A0']) + (self.regularization_rate * self.cache_['W1']) / m
            grads['B1'] = np.sum(error, axis=0)


            return grads

        ## =========================== Regularization L1 =========================== ##

        elif self.regularization == 'l1':

           # Calculate W2 update
            error = 2 * (output - Y) / output.shape[0] * self.softmax(params['Z2'], derivative=True) 
            grads['W2'] = np.outer(error, params['A1']) + (self.regularization_rate * np.sign(self.cache_['W2']))
            grads['B2'] = np.sum(error, axis=0)

            # Calculate W1 update
            if self.activation == 'relu':
                error = np.dot(params['W2'].T, error) * self.relu(params['Z1'], derivative=True)
            elif self.activation == 'tanh':
                error = np.dot(params['W2'].T, error) * self.tanh(params['Z1'], derivative=True)
            else:
                error = np.dot(params['W2'].T, error) * self.sigmoid(params['Z1'], derivative=True)


            grads['W1'] = np.outer(error, params['A0']) + (self.regularization_rate * np.sign(self.cache_['W1']))
            grads['B1'] = np.sum(error, axis=0)

            return grads


        ## =========================== No Regularization =========================== ##

        else:
            ## Calculate W2 update
            error = 2 * (output - Y) / output.shape[0] * self.softmax(params['Z2'], derivative=True) 
            grads['W2'] = np.outer(error, params['A1']) + (self.regularization_rate * np.sign(self.cache_['W2']))
            grads['B2'] = np.sum(error, axis=0)

            # Calculate W1 update
            if self.activation == 'relu':
                error = np.dot(params['W2'].T, error) * self.relu(params['Z1'], derivative=True)
            elif self.activation == 'tanh':
                error = np.dot(params['W2'].T, error) * self.tanh(params['Z1'], derivative=True)
            else:
                error = np.dot(params['W2'].T, error) * self.sigmoid(params['Z1'], derivative=True)

            grads['W1'] = np.outer(error, params['A0']) + (self.regularization_rate * np.sign(self.cache_['W1']))
            grads['B1'] = np.sum(error, axis=0)

        return grads

    def cross_entropy(self, output, Y):
        """ 
        This function calculates the cross entropy loss of the network.

        returns
        -------
        [loss]
            the cross entropy loss of the network.
        """
        params = self.cache_
        m = len(Y)

        if self.regularization == 'l1':
            reg_loss = (np.sum(np.abs(params['W1'])) + np.sum(np.abs(params['W2']))) * self.regularization_rate
            loss = -np.sum(Y * np.log(output))
            loss = loss + reg_loss

        elif self.regularization == 'l2':
            reg_loss = (np.sum(np.square(params['W1'])) + np.sum(np.square(params['W2']))) * self.regularization_rate/2
            loss = -np.sum(Y * np.log(output))
            loss = loss + reg_loss
        else:

            loss = -np.sum(Y * np.log(output))

        return loss

    def gradient_descent(self, grads):
        '''
        This function updates the network's parameters using gradient descent.
        '''

        for key, value in grads.items():
            self.cache_[key] -= self.learning_rate * value

    def calculate_accuracy(self, X, Y):
        '''
        This function calculates the accuracy of the network on the given data.
        (Note: this is not the same as cross entropy loss)
        '''
        y_pred = []

        for x, y in zip(X, Y):
            output = self.forward_propagate(x)
            pred = np.argmax(output)
            y_pred.append(pred == np.argmax(y))

        return np.mean(y_pred)

    def fit(self, X, Y):
        """
        This function trains the network on the given data.
        """
        start_time = time.time()
        for epoch in range(self.epochs):
            for x, y in zip(X, Y):
                output = self.forward_propagate(x)
                grads = self.back_propagate(y, output)
                self.gradient_descent(grads)

            error = self.cross_entropy(output, y)
            self.errors_.append(error)
            accuracy = self.calculate_accuracy(X, Y)
            print(
                f'Epoch: {epoch + 1} [==========================] Time: {time.time() - start_time:.2}s | Error: {error * 100:.2f} | Acc: {accuracy * 100:.2f}%')

    def evaluate(self, X, Y):
        """
        This function evaluates the network on the given data.
        (Note: evaluation is done with both cross entropy loss and accuracy)
        """

        for x, y in zip(X, Y):
            output = self.forward_propagate(x)
            loss = self.cross_entropy(output, y)
            accuracy = self.calculate_accuracy(X, Y)

        return print(f'Cross Entropy Testing Error: {loss:.2f} and Accuracy: {accuracy * 100:.2f}%')

    def validation(self, X, Y, k):
        """
        This function does k-fold validation on the given data.
        """
        kf = KFold(n_splits=k)
        kf.get_n_splits(X)

        for fold, (train_index, test_index) in enumerate(kf.split(X)):
            print('===================')
            print(f'Fold: {fold}')
            print('===================\n')

            X_train, X_test = X[train_index], X[test_index]
            Y_train, Y_test = Y[train_index], Y[test_index]

            self.fit(X_train, Y_train)
            self.evaluate(X_test, Y_test)

    def print_weights(self, prompt):
        """
        This function prints the weights of the network.
        """
        W1 = self.cache_['W1']
        W2 = self.cache_['W2']

        print('[=========================================================]')
        print(f'Weight W1 {prompt}: \n{W1}')
        print('[=========================================================]')
        print(f'Weight W2 {prompt}: \n{W2}')
        print('[=========================================================]')

# %% [markdown]
# ```
# HyperParameters:
#     layer_sizes: list of integers, each integer is the size of a layer.
#         Where each integer is the number of nodes in that layer.
#     epochs: integer, number of epochs to train the network.
#     learning_rate: float, learning rate for the network.
#     regularization: string, either 'l1' or 'l2' or 'none'.
#     regularization_rate: float, the regularization rate.
#     activation: string, either 'sigmoid' or 'relu' or 'tanh' for hidden layers only.
# ```

# %%
clf = MultiLayerPerceptron(layer_sizes=[4, 3, 3], epochs=100, learning_rate=0.01, activation='relu')

# %%
clf.fit(x_train, y_train)
# Out:
# Epoch: 1 [==========================] Time: 0.027s | Error: 0.06 | Acc: 66.67%
# Epoch: 2 [==========================] Time: 0.049s | Error: 0.13 | Acc: 66.67%
# Epoch: 3 [==========================] Time: 0.071s | Error: 0.20 | Acc: 66.67%
# Epoch: 4 [==========================] Time: 0.085s | Error: 0.27 | Acc: 66.67%
# Epoch: 5 [==========================] Time: 0.1s | Error: 0.33 | Acc: 66.67%
# Epoch: 6 [==========================] Time: 0.12s | Error: 0.39 | Acc: 66.67%
# Epoch: 7 [==========================] Time: 0.14s | Error: 0.45 | Acc: 66.67%
# Epoch: 8 [==========================] Time: 0.15s | Error: 0.51 | Acc: 66.67%
# Epoch: 9 [==========================] Time: 0.17s | Error: 0.56 | Acc: 66.67%
# Epoch: 10 [==========================] Time: 0.18s | Error: 0.61 | Acc: 66.67%
# Epoch: 11 [==========================] Time: 0.2s | Error: 0.66 | Acc: 66.67%
# Epoch: 12 [==========================] Time: 0.22s | Error: 0.70 | Acc: 66.67%
# Epoch: 13 [==========================] Time: 0.23s | Error: 0.75 | Acc: 66.67%
# Epoch: 14 [==========================] Time: 0.25s | Error: 0.78 | Acc: 66.67%
# Epoch: 15 [==========================] Time: 0.27s | Error: 0.82 | Acc: 66.67%
# Epoch: 16 [==========================] Time: 0.28s | Error: 0.85 | Acc: 66.67%
# Epoch: 17 [==========================] Time: 0.3s | Error: 0.88 | Acc: 66.67%
# Epoch: 18 [==========================] Time: 0.32s | Error: 0.91 | Acc: 66.67%
# Epoch: 19 [==========================] Time: 0.34s | Error: 0.93 | Acc: 66.67%
# Epoch: 20 [==========================] Time: 0.35s | Error: 0.95 | Acc: 66.67%
# Epoch: 21 [==========================] Time: 0.37s | Error: 0.97 | Acc: 66.67%
# Epoch: 22 [==========================] Time: 0.38s | Error: 0.99 | Acc: 66.67%
# Epoch: 23 [==========================] Time: 0.4s | Error: 1.01 | Acc: 66.67%
# Epoch: 24 [==========================] Time: 0.42s | Error: 1.03 | Acc: 66.67%
# Epoch: 25 [==========================] Time: 0.43s | Error: 1.04 | Acc: 66.67%
# Epoch: 26 [==========================] Time: 0.45s | Error: 1.06 | Acc: 66.67%
# Epoch: 27 [==========================] Time: 0.48s | Error: 1.07 | Acc: 66.67%
# Epoch: 28 [==========================] Time: 0.49s | Error: 1.09 | Acc: 66.67%
# Epoch: 29 [==========================] Time: 0.51s | Error: 1.10 | Acc: 66.67%
# Epoch: 30 [==========================] Time: 0.53s | Error: 1.11 | Acc: 66.67%
# Epoch: 31 [==========================] Time: 0.54s | Error: 1.13 | Acc: 66.67%
# Epoch: 32 [==========================] Time: 0.56s | Error: 1.14 | Acc: 66.67%
# Epoch: 33 [==========================] Time: 0.58s | Error: 1.16 | Acc: 66.67%
# Epoch: 34 [==========================] Time: 0.6s | Error: 1.17 | Acc: 66.67%
# Epoch: 35 [==========================] Time: 0.61s | Error: 1.19 | Acc: 66.67%
# Epoch: 36 [==========================] Time: 0.63s | Error: 1.21 | Acc: 66.67%
# Epoch: 37 [==========================] Time: 0.65s | Error: 1.23 | Acc: 66.67%
# Epoch: 38 [==========================] Time: 0.66s | Error: 1.25 | Acc: 66.67%
# Epoch: 39 [==========================] Time: 0.68s | Error: 1.28 | Acc: 66.67%
# Epoch: 40 [==========================] Time: 0.7s | Error: 1.31 | Acc: 66.67%
# Epoch: 41 [==========================] Time: 0.72s | Error: 1.34 | Acc: 66.67%
# Epoch: 42 [==========================] Time: 0.73s | Error: 1.38 | Acc: 66.67%
# Epoch: 43 [==========================] Time: 0.75s | Error: 1.42 | Acc: 66.67%
# Epoch: 44 [==========================] Time: 0.77s | Error: 1.47 | Acc: 66.67%
# Epoch: 45 [==========================] Time: 0.78s | Error: 1.54 | Acc: 66.67%
# Epoch: 46 [==========================] Time: 0.8s | Error: 1.62 | Acc: 66.67%
# Epoch: 47 [==========================] Time: 0.81s | Error: 1.72 | Acc: 66.67%
# Epoch: 48 [==========================] Time: 0.83s | Error: 1.86 | Acc: 66.67%
# Epoch: 49 [==========================] Time: 0.85s | Error: 2.05 | Acc: 66.67%
# Epoch: 50 [==========================] Time: 0.86s | Error: 2.36 | Acc: 66.67%
# Epoch: 51 [==========================] Time: 0.88s | Error: 2.95 | Acc: 66.67%
# Epoch: 52 [==========================] Time: 0.9s | Error: 4.57 | Acc: 66.67%
# Epoch: 53 [==========================] Time: 0.92s | Error: 61.52 | Acc: 66.67%
# Epoch: 54 [==========================] Time: 0.94s | Error: 95.27 | Acc: 67.50%
# Epoch: 55 [==========================] Time: 0.95s | Error: 89.11 | Acc: 74.17%
# Epoch: 56 [==========================] Time: 0.97s | Error: 83.84 | Acc: 80.00%
# Epoch: 57 [==========================] Time: 0.99s | Error: 79.23 | Acc: 85.83%
# Epoch: 58 [==========================] Time: 1.0s | Error: 75.16 | Acc: 86.67%
# Epoch: 59 [==========================] Time: 1.0s | Error: 71.54 | Acc: 87.50%
# Epoch: 60 [==========================] Time: 1.1s | Error: 68.30 | Acc: 90.00%
# Epoch: 61 [==========================] Time: 1.1s | Error: 65.39 | Acc: 91.67%
# Epoch: 62 [==========================] Time: 1.1s | Error: 62.76 | Acc: 91.67%
# Epoch: 63 [==========================] Time: 1.1s | Error: 60.39 | Acc: 92.50%
# Epoch: 64 [==========================] Time: 1.2s | Error: 58.24 | Acc: 93.33%
# Epoch: 65 [==========================] Time: 1.2s | Error: 56.28 | Acc: 93.33%
# Epoch: 66 [==========================] Time: 1.2s | Error: 54.50 | Acc: 94.17%
# Epoch: 67 [==========================] Time: 1.2s | Error: 52.86 | Acc: 94.17%
# Epoch: 68 [==========================] Time: 1.2s | Error: 51.35 | Acc: 94.17%
# Epoch: 69 [==========================] Time: 1.3s | Error: 49.96 | Acc: 94.17%
# Epoch: 70 [==========================] Time: 1.3s | Error: 48.67 | Acc: 94.17%
# Epoch: 71 [==========================] Time: 1.3s | Error: 47.47 | Acc: 94.17%
# Epoch: 72 [==========================] Time: 1.3s | Error: 46.35 | Acc: 94.17%
# Epoch: 73 [==========================] Time: 1.3s | Error: 45.30 | Acc: 94.17%
# Epoch: 74 [==========================] Time: 1.3s | Error: 44.32 | Acc: 94.17%
# Epoch: 75 [==========================] Time: 1.4s | Error: 43.39 | Acc: 94.17%
# Epoch: 76 [==========================] Time: 1.4s | Error: 42.51 | Acc: 94.17%
# Epoch: 77 [==========================] Time: 1.4s | Error: 41.68 | Acc: 94.17%
# Epoch: 78 [==========================] Time: 1.4s | Error: 40.89 | Acc: 94.17%
# Epoch: 79 [==========================] Time: 1.4s | Error: 40.14 | Acc: 94.17%
# Epoch: 80 [==========================] Time: 1.5s | Error: 39.41 | Acc: 94.17%
# Epoch: 81 [==========================] Time: 1.5s | Error: 38.71 | Acc: 94.17%
# Epoch: 82 [==========================] Time: 1.5s | Error: 38.05 | Acc: 94.17%
# Epoch: 83 [==========================] Time: 1.5s | Error: 37.41 | Acc: 93.33%
# Epoch: 84 [==========================] Time: 1.5s | Error: 36.81 | Acc: 94.17%
# Epoch: 85 [==========================] Time: 1.5s | Error: 36.22 | Acc: 94.17%
# Epoch: 86 [==========================] Time: 1.6s | Error: 35.67 | Acc: 94.17%
# Epoch: 87 [==========================] Time: 1.6s | Error: 35.13 | Acc: 94.17%
# Epoch: 88 [==========================] Time: 1.6s | Error: 34.62 | Acc: 94.17%
# Epoch: 89 [==========================] Time: 1.6s | Error: 34.12 | Acc: 94.17%
# Epoch: 90 [==========================] Time: 1.6s | Error: 33.64 | Acc: 94.17%
# Epoch: 91 [==========================] Time: 1.6s | Error: 33.18 | Acc: 94.17%
# Epoch: 92 [==========================] Time: 1.6s | Error: 32.73 | Acc: 94.17%
# Epoch: 93 [==========================] Time: 1.7s | Error: 32.29 | Acc: 94.17%
# Epoch: 94 [==========================] Time: 1.7s | Error: 31.87 | Acc: 94.17%
# Epoch: 95 [==========================] Time: 1.7s | Error: 31.46 | Acc: 94.17%
# Epoch: 96 [==========================] Time: 1.7s | Error: 31.07 | Acc: 94.17%
# Epoch: 97 [==========================] Time: 1.7s | Error: 30.68 | Acc: 94.17%
# Epoch: 98 [==========================] Time: 1.7s | Error: 30.31 | Acc: 94.17%
# Epoch: 99 [==========================] Time: 1.8s | Error: 29.95 | Acc: 94.17%
# Epoch: 100 [==========================] Time: 1.8s | Error: 29.60 | Acc: 94.17%

# %%
clf.evaluate(x_test, y_test)
# Out:
# Cross Entropy Testing Error: 0.05 and Accuracy: 96.67%

# %%
clf.validation(x_train, y_train, k=5)
# Out:
# ===================
# Fold: 0
# ===================
#
# Epoch: 1 [==========================] Time: 0.024s | Error: 29.32 | Acc: 93.75%
# Epoch: 2 [==========================] Time: 0.041s | Error: 29.05 | Acc: 93.75%
# Epoch: 3 [==========================] Time: 0.055s | Error: 28.79 | Acc: 93.75%
# Epoch: 4 [==========================] Time: 0.07s | Error: 28.53 | Acc: 93.75%
# Epoch: 5 [==========================] Time: 0.088s | Error: 28.28 | Acc: 93.75%
# Epoch: 6 [==========================] Time: 0.1s | Error: 28.03 | Acc: 93.75%
# Epoch: 7 [==========================] Time: 0.11s | Error: 27.79 | Acc: 93.75%
# Epoch: 8 [==========================] Time: 0.13s | Error: 27.55 | Acc: 93.75%
# Epoch: 9 [==========================] Time: 0.14s | Error: 27.32 | Acc: 93.75%
# Epoch: 10 [==========================] Time: 0.15s | Error: 27.09 | Acc: 93.75%
# Epoch: 11 [==========================] Time: 0.17s | Error: 26.87 | Acc: 93.75%
# Epoch: 12 [==========================] Time: 0.18s | Error: 26.65 | Acc: 93.75%
# Epoch: 13 [==========================] Time: 0.2s | Error: 26.44 | Acc: 93.75%
# Epoch: 14 [==========================] Time: 0.21s | Error: 26.23 | Acc: 93.75%
# Epoch: 15 [==========================] Time: 0.23s | Error: 26.02 | Acc: 93.75%
# Epoch: 16 [==========================] Time: 0.25s | Error: 25.82 | Acc: 93.75%
# Epoch: 17 [==========================] Time: 0.27s | Error: 25.62 | Acc: 93.75%
# Epoch: 18 [==========================] Time: 0.28s | Error: 25.42 | Acc: 93.75%
# Epoch: 19 [==========================] Time: 0.3s | Error: 25.23 | Acc: 93.75%
# Epoch: 20 [==========================] Time: 0.31s | Error: 25.04 | Acc: 93.75%
# Epoch: 21 [==========================] Time: 0.32s | Error: 24.85 | Acc: 93.75%
# Epoch: 22 [==========================] Time: 0.34s | Error: 24.67 | Acc: 93.75%
# Epoch: 23 [==========================] Time: 0.35s | Error: 24.49 | Acc: 93.75%
# Epoch: 24 [==========================] Time: 0.36s | Error: 24.31 | Acc: 93.75%
# Epoch: 25 [==========================] Time: 0.37s | Error: 24.13 | Acc: 93.75%
# Epoch: 26 [==========================] Time: 0.39s | Error: 23.96 | Acc: 93.75%
# Epoch: 27 [==========================] Time: 0.4s | Error: 23.79 | Acc: 93.75%
# Epoch: 28 [==========================] Time: 0.41s | Error: 23.63 | Acc: 93.75%
# Epoch: 29 [==========================] Time: 0.43s | Error: 23.47 | Acc: 93.75%
# Epoch: 30 [==========================] Time: 0.44s | Error: 23.31 | Acc: 93.75%
# Epoch: 31 [==========================] Time: 0.45s | Error: 23.15 | Acc: 93.75%
# Epoch: 32 [==========================] Time: 0.47s | Error: 22.99 | Acc: 93.75%
# Epoch: 33 [==========================] Time: 0.48s | Error: 22.84 | Acc: 93.75%
# Epoch: 34 [==========================] Time: 0.5s | Error: 22.69 | Acc: 93.75%
# Epoch: 35 [==========================] Time: 0.51s | Error: 22.54 | Acc: 93.75%
# Epoch: 36 [==========================] Time: 0.52s | Error: 22.40 | Acc: 93.75%
# Epoch: 37 [==========================] Time: 0.53s | Error: 22.26 | Acc: 93.75%
# Epoch: 38 [==========================] Time: 0.55s | Error: 22.12 | Acc: 93.75%
# Epoch: 39 [==========================] Time: 0.56s | Error: 21.98 | Acc: 93.75%
# Epoch: 40 [==========================] Time: 0.57s | Error: 21.84 | Acc: 93.75%
# Epoch: 41 [==========================] Time: 0.59s | Error: 21.71 | Acc: 93.75%
# Epoch: 42 [==========================] Time: 0.6s | Error: 21.58 | Acc: 93.75%
# Epoch: 43 [==========================] Time: 0.62s | Error: 21.45 | Acc: 93.75%
# Epoch: 44 [==========================] Time: 0.63s | Error: 21.32 | Acc: 93.75%
# Epoch: 45 [==========================] Time: 0.65s | Error: 21.19 | Acc: 93.75%
# Epoch: 46 [==========================] Time: 0.66s | Error: 21.07 | Acc: 93.75%
# Epoch: 47 [==========================] Time: 0.68s | Error: 20.94 | Acc: 93.75%
# Epoch: 48 [==========================] Time: 0.69s | Error: 20.82 | Acc: 93.75%
# Epoch: 49 [==========================] Time: 0.7s | Error: 20.70 | Acc: 93.75%
# Epoch: 50 [==========================] Time: 0.72s | Error: 20.59 | Acc: 93.75%
# Epoch: 51 [==========================] Time: 0.74s | Error: 20.47 | Acc: 93.75%
# Epoch: 52 [==========================] Time: 0.76s | Error: 20.36 | Acc: 93.75%
# Epoch: 53 [==========================] Time: 0.78s | Error: 20.25 | Acc: 93.75%
# Epoch: 54 [==========================] Time: 0.81s | Error: 20.13 | Acc: 93.75%
# Epoch: 55 [==========================] Time: 0.85s | Error: 20.03 | Acc: 93.75%
# Epoch: 56 [==========================] Time: 0.9s | Error: 19.92 | Acc: 93.75%
# Epoch: 57 [==========================] Time: 0.93s | Error: 19.81 | Acc: 93.75%
# Epoch: 58 [==========================] Time: 0.95s | Error: 19.71 | Acc: 93.75%
# Epoch: 59 [==========================] Time: 0.97s | Error: 19.60 | Acc: 93.75%
# Epoch: 60 [==========================] Time: 1.0s | Error: 19.50 | Acc: 93.75%
# Epoch: 61 [==========================] Time: 1.0s | Error: 19.40 | Acc: 93.75%
# Epoch: 62 [==========================] Time: 1.0s | Error: 19.30 | Acc: 93.75%
# Epoch: 63 [==========================] Time: 1.1s | Error: 19.20 | Acc: 93.75%
# Epoch: 64 [==========================] Time: 1.1s | Error: 19.10 | Acc: 93.75%
# Epoch: 65 [==========================] Time: 1.1s | Error: 19.01 | Acc: 93.75%
# Epoch: 66 [==========================] Time: 1.1s | Error: 18.91 | Acc: 93.75%
# Epoch: 67 [==========================] Time: 1.1s | Error: 18.82 | Acc: 93.75%
# Epoch: 68 [==========================] Time: 1.1s | Error: 18.73 | Acc: 93.75%
# Epoch: 69 [==========================] Time: 1.2s | Error: 18.64 | Acc: 93.75%
# Epoch: 70 [==========================] Time: 1.2s | Error: 18.56 | Acc: 93.75%
# Epoch: 71 [==========================] Time: 1.2s | Error: 18.48 | Acc: 94.79%
# Epoch: 72 [==========================] Time: 1.2s | Error: 18.40 | Acc: 94.79%
# Epoch: 73 [==========================] Time: 1.2s | Error: 18.33 | Acc: 94.79%
# Epoch: 74 [==========================] Time: 1.2s | Error: 18.26 | Acc: 94.79%
# Epoch: 75 [==========================] Time: 1.2s | Error: 18.19 | Acc: 94.79%
# Epoch: 76 [==========================] Time: 1.3s | Error: 18.13 | Acc: 94.79%
# Epoch: 77 [==========================] Time: 1.3s | Error: 18.08 | Acc: 94.79%
# Epoch: 78 [==========================] Time: 1.3s | Error: 18.02 | Acc: 94.79%
# Epoch: 79 [==========================] Time: 1.3s | Error: 17.96 | Acc: 94.79%
# Epoch: 80 [==========================] Time: 1.3s | Error: 17.90 | Acc: 94.79%
# Epoch: 81 [==========================] Time: 1.3s | Error: 17.84 | Acc: 94.79%
# Epoch: 82 [==========================] Time: 1.3s | Error: 17.78 | Acc: 94.79%
# Epoch: 83 [==========================] Time: 1.4s | Error: 17.72 | Acc: 94.79%
# Epoch: 84 [==========================] Time: 1.4s | Error: 17.66 | Acc: 94.79%
# Epoch: 85 [==========================] Time: 1.4s | Error: 17.60 | Acc: 94.79%
# Epoch: 86 [==========================] Time: 1.4s | Error: 17.54 | Acc: 94.79%
# Epoch: 87 [==========================] Time: 1.4s | Error: 17.48 | Acc: 94.79%
# Epoch: 88 [==========================] Time: 1.4s | Error: 17.43 | Acc: 94.79%
# Epoch: 89 [==========================] Time: 1.4s | Error: 17.37 | Acc: 94.79%
# Epoch: 90 [==========================] Time: 1.4s | Error: 17.31 | Acc: 94.79%
# Epoch: 91 [==========================] Time: 1.5s | Error: 17.26 | Acc: 94.79%
# Epoch: 92 [==========================] Time: 1.5s | Error: 17.20 | Acc: 94.79%
# Epoch: 93 [==========================] Time: 1.5s | Error: 17.15 | Acc: 94.79%
# Epoch: 94 [==========================] Time: 1.5s | Error: 17.09 | Acc: 94.79%
# Epoch: 95 [==========================] Time: 1.5s | Error: 17.04 | Acc: 94.79%
# Epoch: 96 [==========================] Time: 1.5s | Error: 16.99 | Acc: 94.79%
# Epoch: 97 [==========================] Time: 1.5s | Error: 16.93 | Acc: 94.79%
# Epoch: 98 [==========================] Time: 1.6s | Error: 16.88 | Acc: 94.79%
# Epoch: 99 [==========================] Time: 1.6s | Error: 16.83 | Acc: 94.79%
# Epoch: 100 [==========================] Time: 1.6s | Error: 16.78 | Acc: 94.79%
# Cross Entropy Testing Error: 0.03 and Accuracy: 95.83%
# ===================
# Fold: 1
# ===================
#
# Epoch: 1 [==========================] Time: 0.015s | Error: 16.79 | Acc: 95.83%
# Epoch: 2 [==========================] Time: 0.03s | Error: 16.75 | Acc: 95.83%
# Epoch: 3 [==========================] Time: 0.044s | Error: 16.70 | Acc: 95.83%
# Epoch: 4 [==========================] Time: 0.057s | Error: 16.66 | Acc: 95.83%
# Epoch: 5 [==========================] Time: 0.068s | Error: 16.61 | Acc: 95.83%
# Epoch: 6 [==========================] Time: 0.08s | Error: 16.57 | Acc: 95.83%
# Epoch: 7 [==========================] Time: 0.093s | Error: 16.53 | Acc: 95.83%
# Epoch: 8 [==========================] Time: 0.11s | Error: 16.49 | Acc: 95.83%
# Epoch: 9 [==========================] Time: 0.12s | Error: 16.45 | Acc: 95.83%
# Epoch: 10 [==========================] Time: 0.14s | Error: 16.41 | Acc: 95.83%
# Epoch: 11 [==========================] Time: 0.15s | Error: 16.37 | Acc: 95.83%
# Epoch: 12 [==========================] Time: 0.16s | Error: 16.33 | Acc: 95.83%
# Epoch: 13 [==========================] Time: 0.18s | Error: 16.29 | Acc: 95.83%
# Epoch: 14 [==========================] Time: 0.19s | Error: 16.25 | Acc: 95.83%
# Epoch: 15 [==========================] Time: 0.2s | Error: 16.21 | Acc: 95.83%
# Epoch: 16 [==========================] Time: 0.21s | Error: 16.17 | Acc: 95.83%
# Epoch: 17 [==========================] Time: 0.23s | Error: 16.14 | Acc: 95.83%
# Epoch: 18 [==========================] Time: 0.24s | Error: 16.10 | Acc: 95.83%
# Epoch: 19 [==========================] Time: 0.25s | Error: 16.06 | Acc: 95.83%
# Epoch: 20 [==========================] Time: 0.27s | Error: 16.03 | Acc: 95.83%
# Epoch: 21 [==========================] Time: 0.28s | Error: 15.99 | Acc: 95.83%
# Epoch: 22 [==========================] Time: 0.29s | Error: 15.96 | Acc: 95.83%
# Epoch: 23 [==========================] Time: 0.31s | Error: 15.92 | Acc: 95.83%
# Epoch: 24 [==========================] Time: 0.32s | Error: 15.89 | Acc: 95.83%
# Epoch: 25 [==========================] Time: 0.33s | Error: 15.86 | Acc: 95.83%
# Epoch: 26 [==========================] Time: 0.35s | Error: 15.82 | Acc: 95.83%
# Epoch: 27 [==========================] Time: 0.36s | Error: 15.79 | Acc: 95.83%
# Epoch: 28 [==========================] Time: 0.38s | Error: 15.76 | Acc: 95.83%
# Epoch: 29 [==========================] Time: 0.39s | Error: 15.72 | Acc: 95.83%
# Epoch: 30 [==========================] Time: 0.4s | Error: 15.69 | Acc: 95.83%
# Epoch: 31 [==========================] Time: 0.42s | Error: 15.66 | Acc: 95.83%
# Epoch: 32 [==========================] Time: 0.43s | Error: 15.63 | Acc: 95.83%
# Epoch: 33 [==========================] Time: 0.45s | Error: 15.60 | Acc: 95.83%
# Epoch: 34 [==========================] Time: 0.46s | Error: 15.57 | Acc: 95.83%
# Epoch: 35 [==========================] Time: 0.47s | Error: 15.54 | Acc: 95.83%
# Epoch: 36 [==========================] Time: 0.48s | Error: 15.51 | Acc: 95.83%
# Epoch: 37 [==========================] Time: 0.5s | Error: 15.48 | Acc: 95.83%
# Epoch: 38 [==========================] Time: 0.51s | Error: 15.44 | Acc: 95.83%
# Epoch: 39 [==========================] Time: 0.52s | Error: 15.41 | Acc: 95.83%
# Epoch: 40 [==========================] Time: 0.54s | Error: 15.38 | Acc: 95.83%
# Epoch: 41 [==========================] Time: 0.55s | Error: 15.35 | Acc: 95.83%
# Epoch: 42 [==========================] Time: 0.57s | Error: 15.31 | Acc: 95.83%
# Epoch: 43 [==========================] Time: 0.59s | Error: 15.28 | Acc: 95.83%
# Epoch: 44 [==========================] Time: 0.6s | Error: 15.25 | Acc: 95.83%
# Epoch: 45 [==========================] Time: 0.62s | Error: 15.22 | Acc: 95.83%
# Epoch: 46 [==========================] Time: 0.63s | Error: 15.19 | Acc: 95.83%
# Epoch: 47 [==========================] Time: 0.64s | Error: 15.16 | Acc: 95.83%
# Epoch: 48 [==========================] Time: 0.66s | Error: 15.13 | Acc: 95.83%
# Epoch: 49 [==========================] Time: 0.67s | Error: 15.10 | Acc: 95.83%
# Epoch: 50 [==========================] Time: 0.68s | Error: 15.07 | Acc: 95.83%
# Epoch: 51 [==========================] Time: 0.69s | Error: 15.04 | Acc: 95.83%
# Epoch: 52 [==========================] Time: 0.71s | Error: 15.02 | Acc: 95.83%
# Epoch: 53 [==========================] Time: 0.72s | Error: 14.99 | Acc: 95.83%
# Epoch: 54 [==========================] Time: 0.73s | Error: 14.96 | Acc: 95.83%
# Epoch: 55 [==========================] Time: 0.74s | Error: 14.93 | Acc: 95.83%
# Epoch: 56 [==========================] Time: 0.76s | Error: 14.90 | Acc: 95.83%
# Epoch: 57 [==========================] Time: 0.77s | Error: 14.87 | Acc: 95.83%
# Epoch: 58 [==========================] Time: 0.79s | Error: 14.85 | Acc: 95.83%
# Epoch: 59 [==========================] Time: 0.81s | Error: 14.82 | Acc: 95.83%
# Epoch: 60 [==========================] Time: 0.82s | Error: 14.79 | Acc: 95.83%
# Epoch: 61 [==========================] Time: 0.84s | Error: 14.77 | Acc: 95.83%
# Epoch: 62 [==========================] Time: 0.85s | Error: 14.74 | Acc: 95.83%
# Epoch: 63 [==========================] Time: 0.86s | Error: 14.71 | Acc: 95.83%
# Epoch: 64 [==========================] Time: 0.88s | Error: 14.69 | Acc: 95.83%
# Epoch: 65 [==========================] Time: 0.89s | Error: 14.66 | Acc: 96.88%
# Epoch: 66 [==========================] Time: 0.9s | Error: 14.64 | Acc: 96.88%
# Epoch: 67 [==========================] Time: 0.92s | Error: 14.61 | Acc: 96.88%
# Epoch: 68 [==========================] Time: 0.93s | Error: 14.59 | Acc: 96.88%
# Epoch: 69 [==========================] Time: 0.94s | Error: 14.56 | Acc: 96.88%
# Epoch: 70 [==========================] Time: 0.96s | Error: 14.54 | Acc: 96.88%
# Epoch: 71 [==========================] Time: 0.97s | Error: 14.51 | Acc: 96.88%
# Epoch: 72 [==========================] Time: 0.99s | Error: 14.49 | Acc: 96.88%
# Epoch: 73 [==========================] Time: 1.0s | Error: 14.46 | Acc: 96.88%
# Epoch: 74 [==========================] Time: 1.0s | Error: 14.44 | Acc: 96.88%
# Epoch: 75 [==========================] Time: 1.0s | Error: 14.42 | Acc: 96.88%
# Epoch: 76 [==========================] Time: 1.0s | Error: 14.39 | Acc: 96.88%
# Epoch: 77 [==========================] Time: 1.1s | Error: 14.37 | Acc: 96.88%
# Epoch: 78 [==========================] Time: 1.1s | Error: 14.35 | Acc: 96.88%
# Epoch: 79 [==========================] Time: 1.1s | Error: 14.32 | Acc: 96.88%
# Epoch: 80 [==========================] Time: 1.1s | Error: 14.30 | Acc: 96.88%
# Epoch: 81 [==========================] Time: 1.1s | Error: 14.28 | Acc: 96.88%
# Epoch: 82 [==========================] Time: 1.1s | Error: 14.25 | Acc: 96.88%
# Epoch: 83 [==========================] Time: 1.1s | Error: 14.23 | Acc: 96.88%
# Epoch: 84 [==========================] Time: 1.2s | Error: 14.21 | Acc: 96.88%
# Epoch: 85 [==========================] Time: 1.2s | Error: 14.19 | Acc: 96.88%
# Epoch: 86 [==========================] Time: 1.2s | Error: 14.17 | Acc: 96.88%
# Epoch: 87 [==========================] Time: 1.2s | Error: 14.15 | Acc: 96.88%
# Epoch: 88 [==========================] Time: 1.2s | Error: 14.12 | Acc: 96.88%
# Epoch: 89 [==========================] Time: 1.2s | Error: 14.10 | Acc: 96.88%
# Epoch: 90 [==========================] Time: 1.2s | Error: 14.08 | Acc: 96.88%
# Epoch: 91 [==========================] Time: 1.2s | Error: 14.06 | Acc: 96.88%
# Epoch: 92 [==========================] Time: 1.3s | Error: 14.04 | Acc: 96.88%
# Epoch: 93 [==========================] Time: 1.3s | Error: 14.02 | Acc: 96.88%
# Epoch: 94 [==========================] Time: 1.3s | Error: 14.00 | Acc: 96.88%
# Epoch: 95 [==========================] Time: 1.3s | Error: 13.98 | Acc: 96.88%
# Epoch: 96 [==========================] Time: 1.3s | Error: 13.96 | Acc: 96.88%
# Epoch: 97 [==========================] Time: 1.3s | Error: 13.94 | Acc: 96.88%
# Epoch: 98 [==========================] Time: 1.3s | Error: 13.92 | Acc: 96.88%
# Epoch: 99 [==========================] Time: 1.4s | Error: 13.90 | Acc: 96.88%
# Epoch: 100 [==========================] Time: 1.4s | Error: 13.89 | Acc: 96.88%
# Cross Entropy Testing Error: 0.04 and Accuracy: 91.67%
# ===================
# Fold: 2
# ===================
#
# Epoch: 1 [==========================] Time: 0.016s | Error: 13.52 | Acc: 94.79%
# Epoch: 2 [==========================] Time: 0.029s | Error: 13.48 | Acc: 94.79%
# Epoch: 3 [==========================] Time: 0.044s | Error: 13.44 | Acc: 94.79%
# Epoch: 4 [==========================] Time: 0.059s | Error: 13.40 | Acc: 94.79%
# Epoch: 5 [==========================] Time: 0.074s | Error: 13.35 | Acc: 94.79%
# Epoch: 6 [==========================] Time: 0.088s | Error: 13.31 | Acc: 94.79%
# Epoch: 7 [==========================] Time: 0.1s | Error: 13.27 | Acc: 94.79%
# Epoch: 8 [==========================] Time: 0.12s | Error: 13.23 | Acc: 94.79%
# Epoch: 9 [==========================] Time: 0.13s | Error: 13.19 | Acc: 94.79%
# Epoch: 10 [==========================] Time: 0.15s | Error: 13.14 | Acc: 94.79%
# Epoch: 11 [==========================] Time: 0.16s | Error: 13.10 | Acc: 94.79%
# Epoch: 12 [==========================] Time: 0.17s | Error: 13.06 | Acc: 94.79%
# Epoch: 13 [==========================] Time: 0.19s | Error: 13.02 | Acc: 94.79%
# Epoch: 14 [==========================] Time: 0.2s | Error: 12.98 | Acc: 94.79%
# Epoch: 15 [==========================] Time: 0.21s | Error: 12.94 | Acc: 94.79%
# Epoch: 16 [==========================] Time: 0.23s | Error: 12.90 | Acc: 94.79%
# Epoch: 17 [==========================] Time: 0.24s | Error: 12.86 | Acc: 94.79%
# Epoch: 18 [==========================] Time: 0.25s | Error: 12.83 | Acc: 94.79%
# Epoch: 19 [==========================] Time: 0.27s | Error: 12.79 | Acc: 95.83%
# Epoch: 20 [==========================] Time: 0.28s | Error: 12.75 | Acc: 95.83%
# Epoch: 21 [==========================] Time: 0.29s | Error: 12.71 | Acc: 95.83%
# Epoch: 22 [==========================] Time: 0.31s | Error: 12.68 | Acc: 95.83%
# Epoch: 23 [==========================] Time: 0.32s | Error: 12.64 | Acc: 95.83%
# Epoch: 24 [==========================] Time: 0.33s | Error: 12.61 | Acc: 95.83%
# Epoch: 25 [==========================] Time: 0.35s | Error: 12.57 | Acc: 95.83%
# Epoch: 26 [==========================] Time: 0.36s | Error: 12.54 | Acc: 95.83%
# Epoch: 27 [==========================] Time: 0.38s | Error: 12.50 | Acc: 95.83%
# Epoch: 28 [==========================] Time: 0.39s | Error: 12.47 | Acc: 95.83%
# Epoch: 29 [==========================] Time: 0.4s | Error: 12.43 | Acc: 95.83%
# Epoch: 30 [==========================] Time: 0.42s | Error: 12.40 | Acc: 95.83%
# Epoch: 31 [==========================] Time: 0.43s | Error: 12.37 | Acc: 95.83%
# Epoch: 32 [==========================] Time: 0.45s | Error: 12.34 | Acc: 95.83%
# Epoch: 33 [==========================] Time: 0.46s | Error: 12.31 | Acc: 95.83%
# Epoch: 34 [==========================] Time: 0.47s | Error: 12.27 | Acc: 95.83%
# Epoch: 35 [==========================] Time: 0.48s | Error: 12.24 | Acc: 95.83%
# Epoch: 36 [==========================] Time: 0.5s | Error: 12.21 | Acc: 95.83%
# Epoch: 37 [==========================] Time: 0.51s | Error: 12.18 | Acc: 95.83%
# Epoch: 38 [==========================] Time: 0.53s | Error: 12.15 | Acc: 95.83%
# Epoch: 39 [==========================] Time: 0.54s | Error: 12.12 | Acc: 95.83%
# Epoch: 40 [==========================] Time: 0.56s | Error: 12.09 | Acc: 95.83%
# Epoch: 41 [==========================] Time: 0.57s | Error: 12.06 | Acc: 95.83%
# Epoch: 42 [==========================] Time: 0.58s | Error: 12.03 | Acc: 95.83%
# Epoch: 43 [==========================] Time: 0.6s | Error: 12.01 | Acc: 95.83%
# Epoch: 44 [==========================] Time: 0.61s | Error: 11.98 | Acc: 95.83%
# Epoch: 45 [==========================] Time: 0.62s | Error: 11.95 | Acc: 95.83%
# Epoch: 46 [==========================] Time: 0.64s | Error: 11.92 | Acc: 95.83%
# Epoch: 47 [==========================] Time: 0.65s | Error: 11.90 | Acc: 95.83%
# Epoch: 48 [==========================] Time: 0.66s | Error: 11.87 | Acc: 95.83%
# Epoch: 49 [==========================] Time: 0.68s | Error: 11.84 | Acc: 95.83%
# Epoch: 50 [==========================] Time: 0.69s | Error: 11.82 | Acc: 95.83%
# Epoch: 51 [==========================] Time: 0.71s | Error: 11.79 | Acc: 95.83%
# Epoch: 52 [==========================] Time: 0.72s | Error: 11.76 | Acc: 95.83%
# Epoch: 53 [==========================] Time: 0.73s | Error: 11.74 | Acc: 95.83%
# Epoch: 54 [==========================] Time: 0.75s | Error: 11.71 | Acc: 95.83%
# Epoch: 55 [==========================] Time: 0.76s | Error: 11.69 | Acc: 95.83%
# Epoch: 56 [==========================] Time: 0.78s | Error: 11.66 | Acc: 95.83%
# Epoch: 57 [==========================] Time: 0.79s | Error: 11.64 | Acc: 95.83%
# Epoch: 58 [==========================] Time: 0.8s | Error: 11.61 | Acc: 95.83%
# Epoch: 59 [==========================] Time: 0.82s | Error: 11.59 | Acc: 95.83%
# Epoch: 60 [==========================] Time: 0.83s | Error: 11.57 | Acc: 95.83%
# Epoch: 61 [==========================] Time: 0.84s | Error: 11.54 | Acc: 95.83%
# Epoch: 62 [==========================] Time: 0.85s | Error: 11.52 | Acc: 95.83%
# Epoch: 63 [==========================] Time: 0.87s | Error: 11.50 | Acc: 95.83%
# Epoch: 64 [==========================] Time: 0.88s | Error: 11.47 | Acc: 95.83%
# Epoch: 65 [==========================] Time: 0.89s | Error: 11.45 | Acc: 95.83%
# Epoch: 66 [==========================] Time: 0.91s | Error: 11.43 | Acc: 95.83%
# Epoch: 67 [==========================] Time: 0.92s | Error: 11.41 | Acc: 95.83%
# Epoch: 68 [==========================] Time: 0.94s | Error: 11.39 | Acc: 95.83%
# Epoch: 69 [==========================] Time: 0.95s | Error: 11.36 | Acc: 95.83%
# Epoch: 70 [==========================] Time: 0.97s | Error: 11.34 | Acc: 95.83%
# Epoch: 71 [==========================] Time: 0.98s | Error: 11.32 | Acc: 95.83%
# Epoch: 72 [==========================] Time: 1.0s | Error: 11.30 | Acc: 95.83%
# Epoch: 73 [==========================] Time: 1.0s | Error: 11.28 | Acc: 95.83%
# Epoch: 74 [==========================] Time: 1.0s | Error: 11.26 | Acc: 95.83%
# Epoch: 75 [==========================] Time: 1.0s | Error: 11.24 | Acc: 95.83%
# Epoch: 76 [==========================] Time: 1.0s | Error: 11.22 | Acc: 95.83%
# Epoch: 77 [==========================] Time: 1.1s | Error: 11.20 | Acc: 95.83%
# Epoch: 78 [==========================] Time: 1.1s | Error: 11.17 | Acc: 95.83%
# Epoch: 79 [==========================] Time: 1.1s | Error: 11.15 | Acc: 95.83%
# Epoch: 80 [==========================] Time: 1.1s | Error: 11.13 | Acc: 95.83%
# Epoch: 81 [==========================] Time: 1.1s | Error: 11.11 | Acc: 95.83%
# Epoch: 82 [==========================] Time: 1.1s | Error: 11.10 | Acc: 95.83%
# Epoch: 83 [==========================] Time: 1.1s | Error: 11.08 | Acc: 95.83%
# Epoch: 84 [==========================] Time: 1.2s | Error: 11.06 | Acc: 95.83%
# Epoch: 85 [==========================] Time: 1.2s | Error: 11.04 | Acc: 95.83%
# Epoch: 86 [==========================] Time: 1.2s | Error: 11.02 | Acc: 95.83%
# Epoch: 87 [==========================] Time: 1.2s | Error: 11.00 | Acc: 95.83%
# Epoch: 88 [==========================] Time: 1.2s | Error: 10.98 | Acc: 95.83%
# Epoch: 89 [==========================] Time: 1.2s | Error: 10.96 | Acc: 95.83%
# Epoch: 90 [==========================] Time: 1.2s | Error: 10.94 | Acc: 95.83%
# Epoch: 91 [==========================] Time: 1.3s | Error: 10.92 | Acc: 95.83%
# Epoch: 92 [==========================] Time: 1.3s | Error: 10.91 | Acc: 95.83%
# Epoch: 93 [==========================] Time: 1.3s | Error: 10.89 | Acc: 95.83%
# Epoch: 94 [==========================] Time: 1.3s | Error: 10.87 | Acc: 95.83%
# Epoch: 95 [==========================] Time: 1.3s | Error: 10.85 | Acc: 95.83%
# Epoch: 96 [==========================] Time: 1.3s | Error: 10.83 | Acc: 95.83%
# Epoch: 97 [==========================] Time: 1.3s | Error: 10.82 | Acc: 95.83%
# Epoch: 98 [==========================] Time: 1.3s | Error: 10.80 | Acc: 95.83%
# Epoch: 99 [==========================] Time: 1.4s | Error: 10.78 | Acc: 95.83%
# Epoch: 100 [==========================] Time: 1.4s | Error: 10.77 | Acc: 95.83%
# Cross Entropy Testing Error: 0.06 and Accuracy: 95.83%
# ===================
# Fold: 3
# ===================
#
# Epoch: 1 [==========================] Time: 0.017s | Error: 11.86 | Acc: 95.83%
# Epoch: 2 [==========================] Time: 0.032s | Error: 11.86 | Acc: 95.83%
# Epoch: 3 [==========================] Time: 0.046s | Error: 11.86 | Acc: 95.83%
# Epoch: 4 [==========================] Time: 0.061s | Error: 11.86 | Acc: 95.83%
# Epoch: 5 [==========================] Time: 0.073s | Error: 11.86 | Acc: 95.83%
# Epoch: 6 [==========================] Time: 0.084s | Error: 11.86 | Acc: 95.83%
# Epoch: 7 [==========================] Time: 0.096s | Error: 11.86 | Acc: 95.83%
# Epoch: 8 [==========================] Time: 0.11s | Error: 11.86 | Acc: 95.83%
# Epoch: 9 [==========================] Time: 0.12s | Error: 11.85 | Acc: 95.83%
# Epoch: 10 [==========================] Time: 0.13s | Error: 11.85 | Acc: 95.83%
# Epoch: 11 [==========================] Time: 0.14s | Error: 11.85 | Acc: 95.83%
# Epoch: 12 [==========================] Time: 0.16s | Error: 11.85 | Acc: 95.83%
# Epoch: 13 [==========================] Time: 0.17s | Error: 11.84 | Acc: 95.83%
# Epoch: 14 [==========================] Time: 0.18s | Error: 11.84 | Acc: 95.83%
# Epoch: 15 [==========================] Time: 0.2s | Error: 11.84 | Acc: 95.83%
# Epoch: 16 [==========================] Time: 0.21s | Error: 11.84 | Acc: 95.83%
# Epoch: 17 [==========================] Time: 0.22s | Error: 11.83 | Acc: 95.83%
# Epoch: 18 [==========================] Time: 0.24s | Error: 11.83 | Acc: 95.83%
# Epoch: 19 [==========================] Time: 0.25s | Error: 11.83 | Acc: 95.83%
# Epoch: 20 [==========================] Time: 0.27s | Error: 11.82 | Acc: 95.83%
# Epoch: 21 [==========================] Time: 0.28s | Error: 11.82 | Acc: 95.83%
# Epoch: 22 [==========================] Time: 0.29s | Error: 11.82 | Acc: 95.83%
# Epoch: 23 [==========================] Time: 0.31s | Error: 11.81 | Acc: 95.83%
# Epoch: 24 [==========================] Time: 0.32s | Error: 11.81 | Acc: 95.83%
# Epoch: 25 [==========================] Time: 0.33s | Error: 11.81 | Acc: 95.83%
# Epoch: 26 [==========================] Time: 0.35s | Error: 11.80 | Acc: 95.83%
# Epoch: 27 [==========================] Time: 0.36s | Error: 11.80 | Acc: 95.83%
# Epoch: 28 [==========================] Time: 0.37s | Error: 11.80 | Acc: 95.83%
# Epoch: 29 [==========================] Time: 0.39s | Error: 11.79 | Acc: 95.83%
# Epoch: 30 [==========================] Time: 0.4s | Error: 11.79 | Acc: 95.83%
# Epoch: 31 [==========================] Time: 0.41s | Error: 11.79 | Acc: 95.83%
# Epoch: 32 [==========================] Time: 0.43s | Error: 11.78 | Acc: 95.83%
# Epoch: 33 [==========================] Time: 0.44s | Error: 11.78 | Acc: 95.83%
# Epoch: 34 [==========================] Time: 0.45s | Error: 11.78 | Acc: 95.83%
# Epoch: 35 [==========================] Time: 0.47s | Error: 11.77 | Acc: 95.83%
# Epoch: 36 [==========================] Time: 0.48s | Error: 11.77 | Acc: 95.83%
# Epoch: 37 [==========================] Time: 0.5s | Error: 11.76 | Acc: 95.83%
# Epoch: 38 [==========================] Time: 0.51s | Error: 11.76 | Acc: 95.83%
# Epoch: 39 [==========================] Time: 0.52s | Error: 11.75 | Acc: 95.83%
# Epoch: 40 [==========================] Time: 0.54s | Error: 11.75 | Acc: 95.83%
# Epoch: 41 [==========================] Time: 0.55s | Error: 11.75 | Acc: 95.83%
# Epoch: 42 [==========================] Time: 0.57s | Error: 11.74 | Acc: 95.83%
# Epoch: 43 [==========================] Time: 0.58s | Error: 11.74 | Acc: 95.83%
# Epoch: 44 [==========================] Time: 0.59s | Error: 11.73 | Acc: 95.83%
# Epoch: 45 [==========================] Time: 0.61s | Error: 11.73 | Acc: 95.83%
# Epoch: 46 [==========================] Time: 0.62s | Error: 11.72 | Acc: 95.83%
# Epoch: 47 [==========================] Time: 0.64s | Error: 11.72 | Acc: 95.83%
# Epoch: 48 [==========================] Time: 0.65s | Error: 11.71 | Acc: 95.83%
# Epoch: 49 [==========================] Time: 0.66s | Error: 11.71 | Acc: 95.83%
# Epoch: 50 [==========================] Time: 0.68s | Error: 11.70 | Acc: 95.83%
# Epoch: 51 [==========================] Time: 0.69s | Error: 11.70 | Acc: 95.83%
# Epoch: 52 [==========================] Time: 0.7s | Error: 11.70 | Acc: 95.83%
# Epoch: 53 [==========================] Time: 0.72s | Error: 11.69 | Acc: 95.83%
# Epoch: 54 [==========================] Time: 0.73s | Error: 11.69 | Acc: 95.83%
# Epoch: 55 [==========================] Time: 0.74s | Error: 11.68 | Acc: 95.83%
# Epoch: 56 [==========================] Time: 0.76s | Error: 11.68 | Acc: 95.83%
# Epoch: 57 [==========================] Time: 0.77s | Error: 11.67 | Acc: 95.83%
# Epoch: 58 [==========================] Time: 0.78s | Error: 11.67 | Acc: 95.83%
# Epoch: 59 [==========================] Time: 0.79s | Error: 11.66 | Acc: 95.83%
# Epoch: 60 [==========================] Time: 0.81s | Error: 11.66 | Acc: 95.83%
# Epoch: 61 [==========================] Time: 0.82s | Error: 11.65 | Acc: 95.83%
# Epoch: 62 [==========================] Time: 0.83s | Error: 11.65 | Acc: 95.83%
# Epoch: 63 [==========================] Time: 0.85s | Error: 11.64 | Acc: 95.83%
# Epoch: 64 [==========================] Time: 0.86s | Error: 11.64 | Acc: 95.83%
# Epoch: 65 [==========================] Time: 0.88s | Error: 11.63 | Acc: 95.83%
# Epoch: 66 [==========================] Time: 0.89s | Error: 11.63 | Acc: 95.83%
# Epoch: 67 [==========================] Time: 0.9s | Error: 11.62 | Acc: 95.83%
# Epoch: 68 [==========================] Time: 0.92s | Error: 11.62 | Acc: 95.83%
# Epoch: 69 [==========================] Time: 0.93s | Error: 11.61 | Acc: 95.83%
# Epoch: 70 [==========================] Time: 0.94s | Error: 11.61 | Acc: 95.83%
# Epoch: 71 [==========================] Time: 0.95s | Error: 11.60 | Acc: 95.83%
# Epoch: 72 [==========================] Time: 0.97s | Error: 11.60 | Acc: 95.83%
# Epoch: 73 [==========================] Time: 0.98s | Error: 11.59 | Acc: 95.83%
# Epoch: 74 [==========================] Time: 0.99s | Error: 11.59 | Acc: 95.83%
# Epoch: 75 [==========================] Time: 1.0s | Error: 11.58 | Acc: 95.83%
# Epoch: 76 [==========================] Time: 1.0s | Error: 11.58 | Acc: 95.83%
# Epoch: 77 [==========================] Time: 1.0s | Error: 11.57 | Acc: 95.83%
# Epoch: 78 [==========================] Time: 1.0s | Error: 11.57 | Acc: 95.83%
# Epoch: 79 [==========================] Time: 1.1s | Error: 11.56 | Acc: 95.83%
# Epoch: 80 [==========================] Time: 1.1s | Error: 11.56 | Acc: 95.83%
# Epoch: 81 [==========================] Time: 1.1s | Error: 11.55 | Acc: 95.83%
# Epoch: 82 [==========================] Time: 1.1s | Error: 11.55 | Acc: 95.83%
# Epoch: 83 [==========================] Time: 1.1s | Error: 11.54 | Acc: 95.83%
# Epoch: 84 [==========================] Time: 1.1s | Error: 11.54 | Acc: 95.83%
# Epoch: 85 [==========================] Time: 1.1s | Error: 11.53 | Acc: 95.83%
# Epoch: 86 [==========================] Time: 1.2s | Error: 11.52 | Acc: 95.83%
# Epoch: 87 [==========================] Time: 1.2s | Error: 11.52 | Acc: 95.83%
# Epoch: 88 [==========================] Time: 1.2s | Error: 11.51 | Acc: 95.83%
# Epoch: 89 [==========================] Time: 1.2s | Error: 11.51 | Acc: 95.83%
# Epoch: 90 [==========================] Time: 1.2s | Error: 11.50 | Acc: 95.83%
# Epoch: 91 [==========================] Time: 1.2s | Error: 11.50 | Acc: 95.83%
# Epoch: 92 [==========================] Time: 1.2s | Error: 11.49 | Acc: 95.83%
# Epoch: 93 [==========================] Time: 1.2s | Error: 11.49 | Acc: 95.83%
# Epoch: 94 [==========================] Time: 1.3s | Error: 11.48 | Acc: 95.83%
# Epoch: 95 [==========================] Time: 1.3s | Error: 11.48 | Acc: 95.83%
# Epoch: 96 [==========================] Time: 1.3s | Error: 11.47 | Acc: 95.83%
# Epoch: 97 [==========================] Time: 1.3s | Error: 11.47 | Acc: 95.83%
# Epoch: 98 [==========================] Time: 1.3s | Error: 11.46 | Acc: 95.83%
# Epoch: 99 [==========================] Time: 1.3s | Error: 11.46 | Acc: 95.83%
# Epoch: 100 [==========================] Time: 1.4s | Error: 11.45 | Acc: 95.83%
# Cross Entropy Testing Error: 0.18 and Accuracy: 95.83%
# ===================
# Fold: 4
# ===================
#
# Epoch: 1 [==========================] Time: 0.016s | Error: 10.87 | Acc: 96.88%
# Epoch: 2 [==========================] Time: 0.033s | Error: 10.84 | Acc: 96.88%
# Epoch: 3 [==========================] Time: 0.047s | Error: 10.80 | Acc: 96.88%
# Epoch: 4 [==========================] Time: 0.06s | Error: 10.77 | Acc: 96.88%
# Epoch: 5 [==========================] Time: 0.071s | Error: 10.74 | Acc: 96.88%
# Epoch: 6 [==========================] Time: 0.088s | Error: 10.71 | Acc: 96.88%
# Epoch: 7 [==========================] Time: 0.1s | Error: 10.68 | Acc: 96.88%
# Epoch: 8 [==========================] Time: 0.11s | Error: 10.65 | Acc: 96.88%
# Epoch: 9 [==========================] Time: 0.13s | Error: 10.63 | Acc: 96.88%
# Epoch: 10 [==========================] Time: 0.14s | Error: 10.60 | Acc: 96.88%
# Epoch: 11 [==========================] Time: 0.16s | Error: 10.57 | Acc: 96.88%
# Epoch: 12 [==========================] Time: 0.17s | Error: 10.55 | Acc: 96.88%
# Epoch: 13 [==========================] Time: 0.18s | Error: 10.52 | Acc: 96.88%
# Epoch: 14 [==========================] Time: 0.2s | Error: 10.50 | Acc: 96.88%
# Epoch: 15 [==========================] Time: 0.21s | Error: 10.47 | Acc: 96.88%
# Epoch: 16 [==========================] Time: 0.23s | Error: 10.45 | Acc: 96.88%
# Epoch: 17 [==========================] Time: 0.24s | Error: 10.43 | Acc: 96.88%
# Epoch: 18 [==========================] Time: 0.25s | Error: 10.40 | Acc: 96.88%
# Epoch: 19 [==========================] Time: 0.27s | Error: 10.38 | Acc: 96.88%
# Epoch: 20 [==========================] Time: 0.28s | Error: 10.36 | Acc: 96.88%
# Epoch: 21 [==========================] Time: 0.29s | Error: 10.33 | Acc: 96.88%
# Epoch: 22 [==========================] Time: 0.3s | Error: 10.31 | Acc: 96.88%
# Epoch: 23 [==========================] Time: 0.32s | Error: 10.29 | Acc: 96.88%
# Epoch: 24 [==========================] Time: 0.33s | Error: 10.27 | Acc: 96.88%
# Epoch: 25 [==========================] Time: 0.34s | Error: 10.24 | Acc: 96.88%
# Epoch: 26 [==========================] Time: 0.36s | Error: 10.22 | Acc: 96.88%
# Epoch: 27 [==========================] Time: 0.37s | Error: 10.20 | Acc: 96.88%
# Epoch: 28 [==========================] Time: 0.39s | Error: 10.18 | Acc: 96.88%
# Epoch: 29 [==========================] Time: 0.4s | Error: 10.16 | Acc: 96.88%
# Epoch: 30 [==========================] Time: 0.42s | Error: 10.14 | Acc: 96.88%
# Epoch: 31 [==========================] Time: 0.43s | Error: 10.11 | Acc: 96.88%
# Epoch: 32 [==========================] Time: 0.45s | Error: 10.09 | Acc: 96.88%
# Epoch: 33 [==========================] Time: 0.46s | Error: 10.07 | Acc: 96.88%
# Epoch: 34 [==========================] Time: 0.47s | Error: 10.05 | Acc: 96.88%
# Epoch: 35 [==========================] Time: 0.49s | Error: 10.03 | Acc: 96.88%
# Epoch: 36 [==========================] Time: 0.5s | Error: 10.01 | Acc: 96.88%
# Epoch: 37 [==========================] Time: 0.51s | Error: 9.99 | Acc: 96.88%
# Epoch: 38 [==========================] Time: 0.53s | Error: 9.97 | Acc: 96.88%
# Epoch: 39 [==========================] Time: 0.54s | Error: 9.95 | Acc: 96.88%
# Epoch: 40 [==========================] Time: 0.55s | Error: 9.93 | Acc: 96.88%
# Epoch: 41 [==========================] Time: 0.57s | Error: 9.91 | Acc: 96.88%
# Epoch: 42 [==========================] Time: 0.58s | Error: 9.89 | Acc: 96.88%
# Epoch: 43 [==========================] Time: 0.6s | Error: 9.87 | Acc: 96.88%
# Epoch: 44 [==========================] Time: 0.62s | Error: 9.85 | Acc: 96.88%
# Epoch: 45 [==========================] Time: 0.63s | Error: 9.83 | Acc: 96.88%
# Epoch: 46 [==========================] Time: 0.64s | Error: 9.81 | Acc: 96.88%
# Epoch: 47 [==========================] Time: 0.65s | Error: 9.79 | Acc: 96.88%
# Epoch: 48 [==========================] Time: 0.67s | Error: 9.77 | Acc: 96.88%
# Epoch: 49 [==========================] Time: 0.68s | Error: 9.75 | Acc: 96.88%
# Epoch: 50 [==========================] Time: 0.69s | Error: 9.73 | Acc: 96.88%
# Epoch: 51 [==========================] Time: 0.71s | Error: 9.71 | Acc: 96.88%
# Epoch: 52 [==========================] Time: 0.72s | Error: 9.70 | Acc: 96.88%
# Epoch: 53 [==========================] Time: 0.73s | Error: 9.68 | Acc: 96.88%
# Epoch: 54 [==========================] Time: 0.75s | Error: 9.66 | Acc: 96.88%
# Epoch: 55 [==========================] Time: 0.76s | Error: 9.64 | Acc: 96.88%
# Epoch: 56 [==========================] Time: 0.77s | Error: 9.62 | Acc: 96.88%
# Epoch: 57 [==========================] Time: 0.79s | Error: 9.60 | Acc: 96.88%
# Epoch: 58 [==========================] Time: 0.8s | Error: 9.58 | Acc: 96.88%
# Epoch: 59 [==========================] Time: 0.81s | Error: 9.57 | Acc: 96.88%
# Epoch: 60 [==========================] Time: 0.82s | Error: 9.55 | Acc: 96.88%
# Epoch: 61 [==========================] Time: 0.84s | Error: 9.53 | Acc: 96.88%
# Epoch: 62 [==========================] Time: 0.85s | Error: 9.51 | Acc: 96.88%
# Epoch: 63 [==========================] Time: 0.87s | Error: 9.49 | Acc: 96.88%
# Epoch: 64 [==========================] Time: 0.88s | Error: 9.48 | Acc: 96.88%
# Epoch: 65 [==========================] Time: 0.9s | Error: 9.46 | Acc: 96.88%
# Epoch: 66 [==========================] Time: 0.91s | Error: 9.44 | Acc: 96.88%
# Epoch: 67 [==========================] Time: 0.92s | Error: 9.42 | Acc: 96.88%
# Epoch: 68 [==========================] Time: 0.94s | Error: 9.41 | Acc: 96.88%
# Epoch: 69 [==========================] Time: 0.95s | Error: 9.39 | Acc: 96.88%
# Epoch: 70 [==========================] Time: 0.96s | Error: 9.37 | Acc: 96.88%
# Epoch: 71 [==========================] Time: 0.97s | Error: 9.36 | Acc: 96.88%
# Epoch: 72 [==========================] Time: 0.99s | Error: 9.34 | Acc: 96.88%
# Epoch: 73 [==========================] Time: 1.0s | Error: 9.32 | Acc: 96.88%
# Epoch: 74 [==========================] Time: 1.0s | Error: 9.31 | Acc: 96.88%
# Epoch: 75 [==========================] Time: 1.0s | Error: 9.29 | Acc: 96.88%
# Epoch: 76 [==========================] Time: 1.0s | Error: 9.27 | Acc: 96.88%
# Epoch: 77 [==========================] Time: 1.1s | Error: 9.26 | Acc: 96.88%
# Epoch: 78 [==========================] Time: 1.1s | Error: 9.24 | Acc: 96.88%
# Epoch: 79 [==========================] Time: 1.1s | Error: 9.22 | Acc: 96.88%
# Epoch: 80 [==========================] Time: 1.1s | Error: 9.21 | Acc: 96.88%
# Epoch: 81 [==========================] Time: 1.1s | Error: 9.19 | Acc: 96.88%
# Epoch: 82 [==========================] Time: 1.1s | Error: 9.18 | Acc: 96.88%
# Epoch: 83 [==========================] Time: 1.1s | Error: 9.16 | Acc: 96.88%
# Epoch: 84 [==========================] Time: 1.2s | Error: 9.14 | Acc: 96.88%
# Epoch: 85 [==========================] Time: 1.2s | Error: 9.13 | Acc: 96.88%
# Epoch: 86 [==========================] Time: 1.2s | Error: 9.11 | Acc: 96.88%
# Epoch: 87 [==========================] Time: 1.2s | Error: 9.10 | Acc: 96.88%
# Epoch: 88 [==========================] Time: 1.2s | Error: 9.08 | Acc: 96.88%
# Epoch: 89 [==========================] Time: 1.2s | Error: 9.07 | Acc: 96.88%
# Epoch: 90 [==========================] Time: 1.2s | Error: 9.05 | Acc: 96.88%
# Epoch: 91 [==========================] Time: 1.2s | Error: 9.03 | Acc: 96.88%
# Epoch: 92 [==========================] Time: 1.3s | Error: 9.02 | Acc: 96.88%
# Epoch: 93 [==========================] Time: 1.3s | Error: 9.00 | Acc: 96.88%
# Epoch: 94 [==========================] Time: 1.3s | Error: 8.99 | Acc: 96.88%
# Epoch: 95 [==========================] Time: 1.3s | Error: 8.97 | Acc: 96.88%
# Epoch: 96 [==========================] Time: 1.3s | Error: 8.96 | Acc: 96.88%
# Epoch: 97 [==========================] Time: 1.3s | Error: 8.94 | Acc: 96.88%
# Epoch: 98 [==========================] Time: 1.3s | Error: 8.93 | Acc: 96.88%
# Epoch: 99 [==========================] Time: 1.4s | Error: 8.92 | Acc: 96.88%
# Epoch: 100 [==========================] Time: 1.4s | Error: 8.90 | Acc: 96.88%
# Cross Entropy Testing Error: 0.06 and Accuracy: 95.83%

# %%
plt.plot(range(1, len(clf.errors_) + 1), clf.errors_, 'b', label='Training error')
plt.title('Cross entropy loss vs Epochs')
plt.xlabel('Epoch')
plt.ylabel('Cross entropy loss')
# plt.ylim(ymin=0)
plt.legend()
plt.show()
